# %% [markdown]
# <a href="https://colab.research.google.com/github/itsayushiii/Machine-Learning-models-using-tensorflow/blob/main/train_test_split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df  =pd.read_csv('/content/drive/MyDrive/datasets/car detail.csv')
df
# Out:
#     mileage  age  sell price
# 0     69000    6       18000
# 1     35000    3       34000
# 2     57000    5       26100
# 3     22500    2       40000
# 4     66000    4       31500
# 5     59000    5       26750
# 6     52000    5       32000
# 7     72000    6       19300
# 8     91000    8       12000
# 9     67000    6       22000
# 10    83000    7       18700
# 11    79000    7       19500
# 12    59000    5       26000
# 13    58780    4       27500
# 14    82450    7       19400
# 15    35400    3       35000
# 16    28000    2       35500
# 17    69000    5       19700
# 18    87600    8       12800
# 19    52000    5       28200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['mileage'],df['sell price'])

# %%
plt.scatter(df['age'],df['mileage'])

# %%
x = df[['mileage','age']]
y = df['sell price']

# %%
x
# Out:
#     mileage  age
# 0     69000    6
# 1     35000    3
# 2     57000    5
# 3     22500    2
# 4     66000    4
# 5     59000    5
# 6     52000    5
# 7     72000    6
# 8     91000    8
# 9     67000    6
# 10    83000    7
# 11    79000    7
# 12    59000    5
# 13    58780    4
# 14    82450    7
# 15    35400    3
# 16    28000    2
# 17    69000    5
# 18    87600    8
# 19    52000    5

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35500
# 17    19700
# 18    12800
# 19    28200
# Name: sell price, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2, random_state = 10)

# %%
x_train
# Out:
#     mileage  age
# 3     22500    2
# 18    87600    8
# 13    58780    4
# 2     57000    5
# 14    82450    7
# 8     91000    8
# 17    69000    5
# 16    28000    2
# 19    52000    5
# 12    59000    5
# 11    79000    7
# 1     35000    3
# 0     69000    6
# 15    35400    3
# 4     66000    4
# 9     67000    6

# %%
x_test
# Out:
#     mileage  age
# 7     72000    6
# 10    83000    7
# 5     59000    5
# 6     52000    5

# %%
y_train
# Out:
# 3     40000
# 18    12800
# 13    27500
# 2     26100
# 14    19400
# 8     12000
# 17    19700
# 16    35500
# 19    28200
# 12    26000
# 11    19500
# 1     34000
# 0     18000
# 15    35000
# 4     31500
# 9     22000
# Name: sell price, dtype: int64

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: sell price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([21092.81589627, 16874.36749353, 25568.33102927, 26468.06458516])

# %%
y_test
# Out:
# 7     19300
# 10    18700
# 5     26750
# 6     32000
# Name: sell price, dtype: int64

# %%
clf.score(x_test,y_test)
# Out:
# 0.6830166156819483
