# %% [markdown]
# <a href="https://colab.research.google.com/github/itsayushiii/Machine-Learning-models-using-tensorflow/blob/main/Logistic%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/datasets/insurance sample.csv")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance, marker = '+',color = 'red')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.5)

# %%
x_test
# Out:
#     age
# 6    55
# 25   54
# 2    47
# 15   55
# 12   27
# 8    62
# 23   45
# 3    52
# 19   18
# 0    22
# 9    61
# 26   29
# 20   21
# 24   50

# %%
x_train
# Out:
#     age
# 17   58
# 4    46
# 11   28
# 10   18
# 5    56
# 22   40
# 14   49
# 18    9
# 21   26
# 7    60
# 1    25
# 16    5
# 13   29

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 1, 0, 0, 1, 0, 0, 1])

# %%
y_test
# Out:
# 6     0
# 25    1
# 2     1
# 15    1
# 12    0
# 8     1
# 23    1
# 3     0
# 19    0
# 0     0
# 9     1
# 26    0
# 20    0
# 24    1
# Name: bought_insurance, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.8571428571428571

# %%
model.predict_proba(x_test)
# Out:
# array([[0.09046883, 0.90953117],
#        [0.09905816, 0.90094184],
#        [0.18147278, 0.81852722],
#        [0.09046883, 0.90953117],
#        [0.62184964, 0.37815036],
#        [0.04700944, 0.95299056],
#        [0.21315357, 0.78684643],
#        [0.11843308, 0.88156692],
#        [0.80204417, 0.19795583],
#        [0.73073567, 0.26926433],
#        [0.05170721, 0.94829279],
#        [0.57371526, 0.42628474],
#        [0.74998807, 0.25001193],
#        [0.14100448, 0.85899552]])
